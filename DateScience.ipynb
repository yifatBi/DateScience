# %%
import pandas as pd

# %%
data_frame = pd.read_csv('hotels_data.csv')

# %%
data_frame.columns
# Out:
# Index([u'Snapshot ID', u'Snapshot Date', u'Checkin Date', u'Days',
#        u'Original Price', u'Discount Price', u'Discount Code',
#        u'Available Rooms', u'Hotel Name', u'Hotel Stars'],
#       dtype='object')

# %%
data_frame.head()
# Out:
#    Snapshot ID   Snapshot Date    Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00  8/12/2015 0:00     5            1178
# 1            1  7/17/2015 0:00  8/19/2015 0:00     5            1113
# 2            1  7/17/2015 0:00  8/13/2015 0:00     5            4370
# 3            1  7/17/2015 0:00  7/26/2015 0:00     5            1739
# 4            1  7/17/2015 0:00  8/12/2015 0:00     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars
# 0  Best Western Plus Seaport Inn Downtown            3
# 1  Best Western Plus Seaport Inn Downtown            3
# 2                  The Peninsula New York            5
# 3            Eventi Hotel a Kimpton Hotel            4
# 4            Eventi Hotel a Kimpton Hotel            4

# %%
data_frame['Checkin Date']=pd.to_datetime(data_frame['Checkin Date'])
#date_frame['Snapshot Date']=pd.to_datetime(data_frame['Snapshot Date'])

# %%
data_frame['WeekDay']=data_frame['Checkin Date'].dt.dayofweek

# %%
data_frame.head()
# Out:
#    Snapshot ID   Snapshot Date Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00   2015-08-12     5            1178
# 1            1  7/17/2015 0:00   2015-08-19     5            1113
# 2            1  7/17/2015 0:00   2015-08-13     5            4370
# 3            1  7/17/2015 0:00   2015-07-26     5            1739
# 4            1  7/17/2015 0:00   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  WeekDay
# 0  Best Western Plus Seaport Inn Downtown            3        2
# 1  Best Western Plus Seaport Inn Downtown            3        2
# 2                  The Peninsula New York            5        3
# 3            Eventi Hotel a Kimpton Hotel            4        6
# 4            Eventi Hotel a Kimpton Hotel            4        2

# %%
data_frame['DiscountDiff']=data_frame['Original Price']-data_frame['Discount Price']

# %%
data_frame.head()
# Out:
#    Snapshot ID   Snapshot Date Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00   2015-08-12     5            1178
# 1            1  7/17/2015 0:00   2015-08-19     5            1113
# 2            1  7/17/2015 0:00   2015-08-13     5            4370
# 3            1  7/17/2015 0:00   2015-07-26     5            1739
# 4            1  7/17/2015 0:00   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  WeekDay  DiscountDiff
# 0  Best Western Plus Seaport Inn Downtown            3        2           138
# 1  Best Western Plus Seaport Inn Downtown            3        2           131
# 2                  The Peninsula New York            5        3           130
# 3            Eventi Hotel a Kimpton Hotel            4        6            72
# 4            Eventi Hotel a Kimpton Hotel            4        2            67

# %%
data_frame['DiscountPerc']=(data_frame['DiscountDiff']/data_frame['Original Price'])*100

# %%
data_frame.head()
# Out:
#    Snapshot ID Snapshot Date Checkin Date  Days  Original Price  \
# 0            1    2015-07-17   2015-08-12     5            1178
# 1            1    2015-07-17   2015-08-19     5            1113
# 2            1    2015-07-17   2015-08-13     5            4370
# 3            1    2015-07-17   2015-07-26     5            1739
# 4            1    2015-07-17   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  WeekDay  DiscountDiff  \
# 0  Best Western Plus Seaport Inn Downtown            3        2           138
# 1  Best Western Plus Seaport Inn Downtown            3        2           131
# 2                  The Peninsula New York            5        3           130
# 3            Eventi Hotel a Kimpton Hotel            4        6            72
# 4            Eventi Hotel a Kimpton Hotel            4        2            67
#
#    DiscountPerc  DayDiff
# 0     11.714771       26
# 1     11.769991       33
# 2      2.974828       27
# 3      4.140311        9
# 4      3.852789       26

# %%
data_frame['Snapshot Date']=pd.to_datetime(data_frame['Snapshot Date'])

# %%
data_frame.head()
# Out:
#    Snapshot ID Snapshot Date Checkin Date  Days  Original Price  \
# 0            1    2015-07-17   2015-08-12     5            1178
# 1            1    2015-07-17   2015-08-19     5            1113
# 2            1    2015-07-17   2015-08-13     5            4370
# 3            1    2015-07-17   2015-07-26     5            1739
# 4            1    2015-07-17   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  WeekDay  DiscountDiff  \
# 0  Best Western Plus Seaport Inn Downtown            3        2           138
# 1  Best Western Plus Seaport Inn Downtown            3        2           131
# 2                  The Peninsula New York            5        3           130
# 3            Eventi Hotel a Kimpton Hotel            4        6            72
# 4            Eventi Hotel a Kimpton Hotel            4        2            67
#
#    DiscountPerc
# 0      0.117148
# 1      0.117700
# 2      0.029748
# 3      0.041403
# 4      0.038528

# %%
data_frame['DayDiff']=(data_frame['Checkin Date']-data_frame['Snapshot Date']).dt.days

# %%
data_frame.head()
# Out:
#    Snapshot ID Snapshot Date Checkin Date  Days  Original Price  \
# 0            1    2015-07-17   2015-08-12     5            1178
# 1            1    2015-07-17   2015-08-19     5            1113
# 2            1    2015-07-17   2015-08-13     5            4370
# 3            1    2015-07-17   2015-07-26     5            1739
# 4            1    2015-07-17   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  WeekDay  DiscountDiff  \
# 0  Best Western Plus Seaport Inn Downtown            3        2           138
# 1  Best Western Plus Seaport Inn Downtown            3        2           131
# 2                  The Peninsula New York            5        3           130
# 3            Eventi Hotel a Kimpton Hotel            4        6            72
# 4            Eventi Hotel a Kimpton Hotel            4        2            67
#
#    DiscountPerc  DayDiff
# 0     11.714771       26
# 1     11.769991       33
# 2      2.974828       27
# 3      4.140311        9
# 4      3.852789       26

# %%
data_frame.to_csv('Hotels_data_Changed.csv')
