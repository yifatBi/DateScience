# %%
import pandas as pd
#pd.read_csv('hotels_data.csv')

# %%
data_frame = pd.read_csv('hotels_data.csv')

# %%
data_frame.columns
# Out:
# Index([u'Snapshot ID', u'Snapshot Date', u'Checkin Date', u'Days',
#        u'Original Price', u'Discount Price', u'Discount Code',
#        u'Available Rooms', u'Hotel Name', u'Hotel Stars'],
#       dtype='object')

# %%
data_frame.columns
# Out:
# Index([u'Snapshot ID', u'Snapshot Date', u'Checkin Date', u'Days',
#        u'Original Price', u'Discount Price', u'Discount Code',
#        u'Available Rooms', u'Hotel Name', u'Hotel Stars', u'yid'],
#       dtype='object')

# %%
data_frame.head()
# Out:
#    Snapshot ID   Snapshot Date    Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00  8/12/2015 0:00     5            1178
# 1            1  7/17/2015 0:00  8/19/2015 0:00     5            1113
# 2            1  7/17/2015 0:00  8/13/2015 0:00     5            4370
# 3            1  7/17/2015 0:00  7/26/2015 0:00     5            1739
# 4            1  7/17/2015 0:00  8/12/2015 0:00     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  yid
# 0  Best Western Plus Seaport Inn Downtown            3    0
# 1  Best Western Plus Seaport Inn Downtown            3    0
# 2                  The Peninsula New York            5    0
# 3            Eventi Hotel a Kimpton Hotel            4    0
# 4            Eventi Hotel a Kimpton Hotel            4    0

# %%
data_frame['Checkin Date']=pd.to_datetime(data_frame['Checkin Date'])
data_frame['WeekDay']=data_frame['Checkin Date'].dt.dayofweek
#date_frame['Snapshot Date']=pd.to_datetime(data_frame['Snapshot Date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f5740e819e03> in <module>()
#       1 data_frame['Checkin Date']=pd.to_datetime(data_frame['Checkin Date'])
#       2 data_frame['WeekDay']=data_frame['Checkin Date'].dt.dayofweek
# ----> 3 date_frame['Snapshot Date']=pd.to_datetime(data_frame['Snapshot Date'])
#
# NameError: name 'date_frame' is not defined

# %%
data_frame.head()

# %%
data_frame['DiscountDiff']=data_frame['Original Price']-data_frame['Discount Price']

# %%
data_frame.head()
# Out:
#    Snapshot ID   Snapshot Date Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00   2015-08-12     5            1178
# 1            1  7/17/2015 0:00   2015-08-19     5            1113
# 2            1  7/17/2015 0:00   2015-08-13     5            4370
# 3            1  7/17/2015 0:00   2015-07-26     5            1739
# 4            1  7/17/2015 0:00   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  yid  WeekDay  \
# 0  Best Western Plus Seaport Inn Downtown            3    0        2
# 1  Best Western Plus Seaport Inn Downtown            3    0        2
# 2                  The Peninsula New York            5    0        3
# 3            Eventi Hotel a Kimpton Hotel            4    0        6
# 4            Eventi Hotel a Kimpton Hotel            4    0        2
#
#    DiscountDiff
# 0           138
# 1           131
# 2           130
# 3            72
# 4            67

# %%
data_frame['DiscountPerc']=data_frame['DiscountDiff']/data_frame['Original Price']

# %%
data_frame.head()
# Out:
#    Snapshot ID   Snapshot Date Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00   2015-08-12     5            1178
# 1            1  7/17/2015 0:00   2015-08-19     5            1113
# 2            1  7/17/2015 0:00   2015-08-13     5            4370
# 3            1  7/17/2015 0:00   2015-07-26     5            1739
# 4            1  7/17/2015 0:00   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  yid  WeekDay  \
# 0  Best Western Plus Seaport Inn Downtown            3    0        2
# 1  Best Western Plus Seaport Inn Downtown            3    0        2
# 2                  The Peninsula New York            5    0        3
# 3            Eventi Hotel a Kimpton Hotel            4    0        6
# 4            Eventi Hotel a Kimpton Hotel            4    0        2
#
#    DiscountDiff  DiscountPerc
# 0           138      0.117148
# 1           131      0.117700
# 2           130      0.029748
# 3            72      0.041403
# 4            67      0.038528
