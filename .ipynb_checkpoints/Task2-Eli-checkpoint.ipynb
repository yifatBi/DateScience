# %%
import pandas as pd

df = pd.read_csv(r"Hotels_data_Changed.csv")
df.columns
df.head(5)
# Out:
#    Snapshot ID Snapshot Date Checkin Date  Days  Original Price  \
# 0            1    2015-07-17   2015-08-12     5            1178
# 1            1    2015-07-17   2015-08-19     5            1113
# 2            1    2015-07-17   2015-08-13     5            4370
# 3            1    2015-07-17   2015-07-26     5            1739
# 4            1    2015-07-17   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars WeekDay  DiscountDiff  \
# 0  Best Western Plus Seaport Inn Downtown            3     Wed           138
# 1  Best Western Plus Seaport Inn Downtown            3     Wed           131
# 2                  The Peninsula New York            5     Thu           130
# 3            Eventi Hotel a Kimpton Hotel            4     Sun            72
# 4            Eventi Hotel a Kimpton Hotel            4     Wed            67
#
#    DiscountPerc  DayDiff
# 0     11.714771       26
# 1     11.769991       33
# 2      2.974828       27
# 3      4.140311        9
# 4      3.852789       26

# %%
relevantColumns = ['Hotel Name', 'DayDiff', 'Checkin Date', 'Snapshot Date', 'WeekDay', 'Discount Code','DiscountPerc']
relevantColumnsFeaturesWDiscoutCode = relevantColumns[0:6]
relevantColumnsFeatures = relevantColumns[0:5]

df = df[relevantColumns]
df.sort_values(['DiscountPerc'], ascending=False, inplace=True)
df.drop_duplicates(subset=relevantColumnsFeatures, keep='first', inplace=True)
df.dropna()
df.to_csv(r"Hotels_data_filtered.csv")
df.head(5)
# Out:
#                                     Hotel Name  DayDiff Checkin Date  \
# 26262   Hyatt Place Flushing LaGuardia Airport        1   2015-09-03
# 69313          Manhattan Broadway Budget Hotel       21   2015-10-22
# 68905          Manhattan Broadway Budget Hotel       19   2015-10-20
# 146691           Comfort Inn Times Square West        5   2015-12-01
# 140216                 New York Hilton Midtown        2   2015-11-21
#
#        Snapshot Date WeekDay  Discount Code  DiscountPerc
# 26262     2015-09-02     Thu              1     68.425842
# 69313     2015-10-01     Thu              3     68.305669
# 68905     2015-10-01     Tue              2     66.615761
# 146691    2015-11-26     Tue              3     56.410256
# 140216    2015-11-19     Sat              4     54.636591

# %%
#Convert the data to numeric
from sklearn import preprocessing

#Hotel Name
le = preprocessing.LabelEncoder()
le.fit(df['Hotel Name'])
df['Hotel Name'] = le.transform(df['Hotel Name']) 

#WeekDay
le = preprocessing.LabelEncoder()
le.fit(df['WeekDay'])
df['WeekDay'] = le.transform(df['WeekDay']) 

#Snapshot Date
le = preprocessing.LabelEncoder()
le.fit(df['Snapshot Date'])
df['Snapshot Date'] = le.transform(df['Snapshot Date']) 

#Checkin Date
le = preprocessing.LabelEncoder()
le.fit(df['Checkin Date'])
df['Checkin Date'] = le.transform(df['Checkin Date'])

# %%
# Naive Bayes
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score


features = df[relevantColumnsFeatures]
target = df['Discount Code']

f_train, f_test, t_train, t_test = train_test_split(features, target, random_state=1)

nb = GaussianNB()

nb.fit(f_train, t_train)
predicted = nb.predict(f_test)

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np

matrix=pd.DataFrame(
    confusion_matrix(t_test, predicted),
    index=['Predicted 1', 'Predicted 2','Predicted 3','Predicted 4'],
    columns=['True 1', 'True 2','True 3','True 4']
)
print("-------------------------Naive Bayes------------------------")
print("-------------------------STATISTICS-------------------------")
print("confusion_matrix:")
print(matrix)
print("------------------------------------------------------------")
# accuracy
accuracy=accuracy_score(t_test, predicted)
print("accuracy is: %s" %(accuracy))
print("------------------------------------------------------------")
# TP
tp = np.diag(matrix)
print("TP is: %s" %(tp))
print("------------------------------------------------------------")
# FP
fp=matrix.sum(axis=0)-np.diag(matrix)
print("FP:")
print(fp)
print("------------------------------------------------------------")
# FN
fn = matrix.sum(axis=1) - np.diag(matrix)
print("FN:")
print(fn)
print("------------------------------------------------------------")
# ROC
print("ROC:")
# This is the ROC curve
predictProb = nb.predict_proba(f_test)
skplt.metrics.plot_roc_curve(t_test, predictProb)
plt.show()
print("------------------------------------------------------------")
print()
# Out:
# -------------------------Naive Bayes------------------------
# -------------------------STATISTICS-------------------------
# confusion_matrix:
#              True 1  True 2  True 3  True 4
# Predicted 1     594    4963    1105       0
# Predicted 2     589    6086    1686       0
# Predicted 3     394    5210    1887       0
# Predicted 4     422    2978     911       0
# ------------------------------------------------------------
# accuracy is: 0.31936626281453867
# ------------------------------------------------------------
# TP is: [ 594 6086 1887    0]
# ------------------------------------------------------------
# FP:
# True 1     1405
# True 2    13151
# True 3     3702
# True 4        0
# dtype: int64
# ------------------------------------------------------------
# FN:
# Predicted 1    6068
# Predicted 2    2275
# Predicted 3    5604
# Predicted 4    4311
# dtype: int64
# ------------------------------------------------------------
# ROC:
# ------------------------------------------------------------

# %%
# DECISION TREE
from sklearn.tree import DecisionTreeClassifier

tree_cls = DecisionTreeClassifier()
tree_cls.fit(f_train, t_train)
predictedTree = tree_cls.predict(f_test)

# %%
matrix=pd.DataFrame(
    confusion_matrix(t_test, predictedTree),
    index=['Predicted 1', 'Predicted 2','Predicted 3','Predicted 4'],
    columns=['True 1', 'True 2','True 3','True 4']
)
print("-------------------------DECISION TREE------------------------")
print("-------------------------STATISTICS-------------------------")
print("confusion_matrix:")
print(matrix)
print("------------------------------------------------------------")
# accuracy
accuracy=accuracy_score(t_test, predictedTree)
print("accuracy is: %s" %(accuracy))
print("------------------------------------------------------------")
# TP
tp = np.diag(matrix)
print("TP is: %s" %(tp))
print("------------------------------------------------------------")
# FP
fp=matrix.sum(axis=0)-np.diag(matrix)
print("FP:")
print(fp)
print("------------------------------------------------------------")
# FN
fn = matrix.sum(axis=1) - np.diag(matrix)
print("FN:")
print(fn)
print("------------------------------------------------------------")
# ROC
print("ROC:")
# This is the ROC curve
predictProb2 = tree_cls.predict_proba(f_test)
skplt.metrics.plot_roc_curve(t_test, predictProb2)
plt.show()
print("------------------------------------------------------------")
print()
# Out:
# -------------------------DECISION TREE------------------------
# -------------------------STATISTICS-------------------------
# confusion_matrix:
#              True 1  True 2  True 3  True 4
# Predicted 1    5109     759     466     328
# Predicted 2     688    6564     726     383
# Predicted 3     452     840    5812     387
# Predicted 4     298     365     442    3206
# ------------------------------------------------------------
# accuracy is: 0.7713327120223672
# ------------------------------------------------------------
# TP is: [5109 6564 5812 3206]
# ------------------------------------------------------------
# FP:
# True 1    1438
# True 2    1964
# True 3    1634
# True 4    1098
# dtype: int64
# ------------------------------------------------------------
# FN:
# Predicted 1    1553
# Predicted 2    1797
# Predicted 3    1679
# Predicted 4    1105
# dtype: int64
# ------------------------------------------------------------
# ROC:
# ------------------------------------------------------------

# %%
from IPython.display import display, HTML

#The must impact feature
print("----------------The must impact feature---------------------")
t = pd.DataFrame({'Feature Name':f_test.columns.values, 'Importances':tree_cls.feature_importances_})
t.sort_values(['Importances'], ascending= False, inplace=True)
display(HTML(t.to_html(index=False)))
print("------------------------------------------------------------")
print()
# Out:
# ----------------The must impact feature---------------------
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Feature Name</th>
#       <th>Importances</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Hotel Name</td>
#       <td>0.363621</td>
#     </tr>
#     <tr>
#       <td>Snapshot Date</td>
#       <td>0.229809</td>
#     </tr>
#     <tr>
#       <td>Checkin Date</td>
#       <td>0.203619</td>
#     </tr>
#     <tr>
#       <td>DayDiff</td>
#       <td>0.169131</td>
#     </tr>
#     <tr>
#       <td>WeekDay</td>
#       <td>0.033821</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------------------------------------
